# %% [markdown]
# # Isomaps

# %% [markdown]
# Credit Card Dataset

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.manifold import Isomap
from sklearn.cluster import KMeans
from sklearn import metrics

# Load the dataset
data = pd.read_csv("Datasets/CC GENERAL.csv")

# Drop unnecessary columns
data.drop(["CUST_ID"], axis = 1, inplace = True)

# Replace missing values with column means
data.fillna(data.mean(), inplace = True)

# Create Isomap object
isomap = Isomap(n_components = 2)

# Fit and transform the data with Isomap
isomap_data = isomap.fit_transform(data)

# %%
# Compute the optimal k value using the elbow method
inertias = []
silhouettes = []
ks = range(2, 11)
for k in ks:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(isomap_data)
    inertias.append(kmeans.inertia_)
    silhouettes.append(metrics.silhouette_score(isomap_data, kmeans.labels_))
    
# Plot the elbow curve to find the optimal k value
plt.plot(ks, inertias, 'bx-')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method For Optimal k')
plt.show()

# Plot the silhouette scores to help evaluate the optimal k value
plt.plot(ks, silhouettes, 'bx-')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Scores for Optimal k')
plt.show()

# %%
# Perform k-means clustering on the transformed data with optimal k
optimal_k = 6  # Set to the k value with the elbow method or another method of your choice
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
kmeans_clusters = kmeans.fit_predict(isomap_data)

# Create a scatter plot of the transformed data, colored by cluster
plt.scatter(isomap_data[:, 0], isomap_data[:, 1], c=kmeans_clusters)
plt.title(f"K-Means Clustering of Isomap Transformed Credit Card Dataset with {optimal_k} clusters")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.show()

# %% [markdown]
# Fractional Abundances of Cells Classified within 2.5 Hours of Movement

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.manifold import Isomap
from sklearn.cluster import KMeans
from sklearn import metrics

# Load the dataset
data = pd.read_excel('Datasets/media-2.xlsx')

# Drop unnecessary columns
data.drop(["Condition number", "Total cells  per condition", "Condition name (Description of perturbation, dimensionality, cell line name, etc.)", "Condition Information/source "], axis = 1, inplace = True)
data = data.fillna(0)

# Replace missing values with column means
data.fillna(data.mean(), inplace = True)

# %%
# Create Isomap object
isomap = Isomap(n_components = 2)

# Fit and transform the data with Isomap
isomap_data = isomap.fit_transform(data)

# Plot the results
import matplotlib.pyplot as plt
plt.scatter(isomap_data[:, 0], isomap_data[:, 1], cmap="coolwarm")
plt.title("Isomap Manifold Learning Results")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.show()

# %%
# Compute the optimal k value using the elbow method
inertias = []
silhouettes = []
ks = range(2, 30)
for k in ks:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(isomap_data)
    inertias.append(kmeans.inertia_)
    silhouettes.append(metrics.silhouette_score(isomap_data, kmeans.labels_))
    
# Plot the elbow curve to find the optimal k value
plt.plot(ks, inertias, 'bx-')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method For Optimal k')
plt.show()

# Plot the silhouette scores to help evaluate the optimal k value
plt.plot(ks, silhouettes, 'bx-')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Scores for Optimal k')
plt.show()

# %%
# Perform k-means clustering on the transformed data with optimal k
optimal_k = 15  # Set to the k value with the elbow method or another method of your choice
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
kmeans_clusters = kmeans.fit_predict(isomap_data)

# Create a scatter plot of the transformed data, colored by cluster
plt.scatter(isomap_data[:, 0], isomap_data[:, 1], c=kmeans_clusters)
plt.title(f"K-Means Clustering of Isomap Transformed Fractional Abundances of Cells with {optimal_k} clusters")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.show()

# %% [markdown]
# Slide-seqV2 Data of the Human Testis

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.manifold import Isomap
from sklearn.cluster import KMeans
from sklearn import metrics

# Load the dataset
data = pd.read_csv("Datasets/hum_niche.csv", low_memory=False)

data.fillna(data.mean(), inplace = True)
data = data.fillna(0)

data = data.replace('$', '')
data = data.replace('', pd.np.nan)
data = data.fillna(0)
data = data.select_dtypes(include=['float64', 'int64']) # only keep columns with float or int data types
data = data.dropna(axis=1, how='any') # drop columns containing any NaN values
data = data.astype(int)
# Out:
# <ipython-input-8-a0e876f60ee7>:16: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   data = data.replace('', pd.np.nan)

# %%
# Create Isomap object
isomap = Isomap(n_components = 2)

# Fit and transform the data with Isomap
isomap_data = isomap.fit_transform(data)

# Plot the results
import matplotlib.pyplot as plt
plt.scatter(isomap_data[:, 0], isomap_data[:, 1], cmap="coolwarm")
plt.title("Isomap Manifold Learning Results")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.show()

# %%
# Compute the optimal k value using the elbow method
inertias = []
silhouettes = []
ks = range(40, 100)
for k in ks:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(isomap_data)
    inertias.append(kmeans.inertia_)
    silhouettes.append(metrics.silhouette_score(isomap_data, kmeans.labels_))
    
# Plot the elbow curve to find the optimal k value
plt.plot(ks, inertias, 'bx-')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method For Optimal k')
plt.show()

# Plot the silhouette scores to help evaluate the optimal k value
plt.plot(ks, silhouettes, 'bx-')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Scores for Optimal k')
plt.show()

# %%
# Perform k-means clustering on the transformed data with optimal k
optimal_k = 85  # Set to the k value with the elbow method or another method of your choice
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
kmeans_clusters = kmeans.fit_predict(isomap_data)

# %%
# Create a scatter plot of the transformed data, colored by cluster
plt.scatter(isomap_data[:, 0], isomap_data[:, 1], c=kmeans_clusters)
plt.title(f"K-Means Clustering of Isomap Transformed Slide-seqV2 Data of the Human Testis with {optimal_k} clusters")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.ylim(-10000, 17500)
plt.xlim(-10000, 20000)
plt.show()
